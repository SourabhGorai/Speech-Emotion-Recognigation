# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        paths.append(os.path.join(dirname, filename))
        # print(filename)
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
# Create a Dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  D:/01Old/Python/Projects/speech emotion recogn...  angry
# 1  D:/01Old/Python/Projects/speech emotion recogn...  angry
# 2  D:/01Old/Python/Projects/speech emotion recogn...  angry
# 3  D:/01Old/Python/Projects/speech emotion recogn...  angry
# 4  D:/01Old/Python/Projects/speech emotion recogn...  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      800
# disgust    800
# fear       800
# happy      800
# neutral    800
# ps         800
# sad        800
# Name: count, dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
# sns.countplot(df['label'])
sns.countplot(data=df, x='label', orient='h')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
# def waveplot(data, sr, emotion):
#     plt.figure(figsize =(10,4))
#     plt.title("Emotion", size = 20)
#     librosa.display.waveplot(data, sr=sr)
#     plt.show()

# def spectogram(data,sr,emotion):
#     x = librosa.stft(data)
#     xdb = librosa.amplitude_to_db(abs(x))
#     plt.figure(figsize =(10,4))
#     plt.title("Emotion", size = 20)
#     librosa.display.specshow(xdb, sr=sr, x_axis = 'time', y_axis = 'hz')
#     plt.colorbar()

# Define functions for visualization
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(f"Waveplot for Emotion: {emotion}", size=20)
    librosa.display.waveshow(data, sr=sr)  # Note: librosa.display.waveplot is deprecated
    plt.show()

def spectrogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(10, 4))
    plt.title(f"Spectrogram for Emotion: {emotion}", size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()
    plt.show()

# %%
# Process the selected emotion
emotion = 'fear'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for fear: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_Fear\OAF_back_fear.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'angry'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for angry: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_angry\OAF_back_angry.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'disgust'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for disgust: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_disgust\OAF_back_disgust.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'neutral'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for neutral: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_neutral\OAF_back_neutral.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'sad'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for sad: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_Sad\OAF_back_sad.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'ps'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for ps: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_Pleasant_surprise\OAF_back_ps.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Process the selected emotion
emotion = 'happy'
filtered_df = df[df['label'] == emotion]

# Check if any files are available for the selected emotion
if not filtered_df.empty:
    path = filtered_df['speech'].values
    file_path = path[0]  # Access the first audio file path
    data, sampling_rate = librosa.load(file_path)
    
    # Display the audio file (Optional)
    print(f"Playing audio for {emotion}: {file_path}")
    display(Audio(data=data, rate=sampling_rate))
    
    # Visualize
    waveplot(data, sampling_rate, emotion)
    spectrogram(data, sampling_rate, emotion)
else:
    print(f"No files found for the emotion: {emotion}")
# Out:
# Playing audio for happy: D:/01Old/Python/Projects/speech emotion recogningation/TESS Toronto emotional speech set data\OAF_happy\OAF_back_happy.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration = 3, offset = 0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis =0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666927e+01,
#        -2.11275601e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228313e+00, -5.57366073e-01, -1.83255327e+00,  2.02101663e-01,
#         7.27551162e-01,  1.31773746e+00,  2.88633752e+00,  2.85579062e+00,
#        -4.71292210e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126190e+00, -1.79688025e+00, -7.03765249e+00,  9.43658352e+00,
#         8.35585403e+00,  2.17123604e+01,  1.92169914e+01,  2.03489285e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722193e-01,  5.11131525e+00,
#         9.56873894e+00,  5.45486879e+00,  2.50996351e+00, -1.82390785e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08914971e+00, -1.90649164e+00],
#       dtype=float32)

# %%
x_mfcc = df['speech'].apply(lambda x : extract_mfcc(x))

# %%
x_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666693, -...
# 1       [-465.73267, 98.77373, 0.65600884, -32.74544, ...
# 2       [-429.79196, 46.12401, 1.5550481, -0.21709459,...
# 3       [-403.46118, 76.32369, -12.531775, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8654995, 16.092943, 8...
#                               ...
# 5595    [-406.48053, 80.379875, 32.462395, 46.579094, ...
# 5596    [-426.90918, 102.54756, 24.800041, 43.04809, 4...
# 5597    [-378.50494, 80.91062, 35.300533, 39.74792, -4...
# 5598    [-434.8618, 89.90637, 28.373262, 39.57707, -2....
# 5599    [-421.8341, 70.69788, 32.476387, 45.642555, 4....
# Name: speech, Length: 5600, dtype: object

# %%
x = [x for x in x_mfcc]
x = np.array(x)
x.shape
# Out:
# (5600, 40)

# %%
# Input Split

x=np.expand_dims(x, -1)
x.shape
# length of dataet
# column length
# 1
# Out:
# (5600, 40, 1)

# %%
# One Hot Encoding
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %% [markdown]
# Building LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(128, return_sequences=False, input_shape=(40,1)),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ...

# %% [markdown]
# Train the Model

# %%
history = model.fit(x,y,validation_split=0.2, epochs=100, batch_size=512, shuffle=True)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - accuracy: 0.1775 - loss: 1.8919 - val_accuracy: 0.5179 - val_loss: 1.7139
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.3622 - loss: 1.6595 - val_accuracy: 0.5312 - val_loss: 1.4085
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.5182 - loss: 1.3356 - val_accuracy: 0.6304 - val_loss: 0.9824
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.6161 - loss: 1.0134 - val_accuracy: 0.7009 - val_loss: 0.7544
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.7154 - loss: 0.7675 - val_accuracy: 0.7893 - val_loss: 0.5744
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.7852 - loss: 0.5720 - val_accuracy: 0.8759 - val_loss: 0.3973
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.8352 - loss: 0.4745 - val_accuracy: 0.8973 - val_loss: 0.2973
# Epoch 8/100
# ...

# %% [markdown]
# Plot the Results

# %%
epochs = list(range(100))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label = 'train accuracy')
plt.plot(epochs, val_acc, label = 'val_accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label = 'train loss')
plt.plot(epochs, val_loss, label = 'val_loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
emotions = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'ps', 'sad']

# %%
# Function to Predict Emotion for New Audio
def predict_emotion(audio_path, model):
    # Load the audio file
    data, sampling_rate = librosa.load(audio_path, duration=3, offset=0.5)
    # Extract MFCC features
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sampling_rate, n_mfcc=40).T, axis=0)
    mfcc = mfcc.reshape(1, 40, 1)  # Reshape to match model input shape
    
    # Make a prediction
    prediction = model.predict(mfcc)
    
    # Get the predicted emotion index
    predicted_label_index = np.argmax(prediction, axis=1)[0]
    
    # Map the predicted index to the corresponding emotion label
    predicted_emotion = emotions[predicted_label_index]
    
    print(f"The predicted emotion is: {predicted_emotion}")
    return predicted_emotion

# %%
# Test Prediction with New Audio File
test_audio_path = 'D:\\01Old\\Python\\Projects\\speech emotion recogningation\\TESS Toronto emotional speech set data\\YAF_happy\\YAF_boat_happy.wav'
predicted_emotion = predict_emotion(test_audio_path, model)

# Display Waveplot and Spectrogram of Test Audio
data, sr = librosa.load(test_audio_path, duration=3, offset=0.5)
waveplot(data, sr, predicted_emotion)
spectrogram(data, sr, predicted_emotion)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# The predicted emotion is: happy
